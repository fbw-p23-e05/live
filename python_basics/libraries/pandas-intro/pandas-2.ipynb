# %%
import pandas as pd

# %%
df = pd.read_csv("states_by_country_code.csv")

# %%
df.shape
# Out:
# (4989, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4989 entries, 0 to 4988
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State Code    4984 non-null   object
#  1   State Name    4989 non-null   object
#  2   Country Code  4975 non-null   object
# dtypes: object(3)
# memory usage: 117.1+ KB

# %%
df.describe()
# Out:
#        State Code        State Name Country Code
# count        4984              4989         4975
# unique       1677              4898          200
# top             5  Western Province           GB
# freq           65                 5          247

# %%
df.columns
# Out:
# Index(['State Code', 'State Name', 'Country Code'], dtype='object')

# %%
df.isnull()
# Out:
#       State Code  State Name  Country Code
# 0          False       False         False
# 1          False       False         False
# 2          False       False         False
# 3          False       False         False
# 4          False       False         False
# ...          ...         ...           ...
# 4984       False       False         False
# 4985       False       False         False
# 4986       False       False         False
# 4987       False       False         False
# 4988       False       False         False
#
# [4989 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# State Code       5
# State Name       0
# Country Code    14
# dtype: int64

# %%
df["State Name"]
# Out:
# 0                        Badakhshan
# 1                           Badghis
# 2                           Baghlan
# 3                             Balkh
# 4                            Bamyan
#                    ...
# 4984      Mashonaland West Province
# 4985              Masvingo Province
# 4986    Matabeleland North Province
# 4987    Matabeleland South Province
# 4988              Midlands Province
# Name: State Name, Length: 4989, dtype: object

# %%
df["State Code"]
# Out:
# 0       BDS
# 1       BDG
# 2       BGL
# 3       BAL
# 4       BAM
#        ...
# 4984     MW
# 4985     MV
# 4986     MN
# 4987     MS
# 4988     MI
# Name: State Code, Length: 4989, dtype: object

# %%
df2 = df[["State Code", "State Name"]]

# %% [markdown]
# # Cleaning the data

# %%
# Drop the missing values
df3 = df.copy()
df3 = df3.dropna()
df3.shape
df3.isnull().sum()
# Out:
# State Code      0
# State Name      0
# Country Code    0
# dtype: int64

# %%
# Replace the missing values
df4 = df.copy()
df4 = df4.fillna("Null")
df4.isnull().sum()
# Out:
# State Code      0
# State Name      0
# Country Code    0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
df["Country Code"].value_counts().plot(kind='pie', figsize=(30, 15))
# Out:
# <Axes: ylabel='count'>
